# %%
import cv2
import os

# %%
df_train = cv2.imread_csv("./APTOS/train.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7f5bdd2a7554> in <module>
# ----> 1 df_train = cv2.imread_csv("./APTOS/train.csv")
#
# AttributeError: module 'cv2' has no attribute 'imread_csv'

# %%
def save_No_DR_img(imgs, target_dir, class_label='0'):
    fig, axis = plt.subplots(2, 6, figsize=(15, 6))
    for idnx, (idx, row) in enumerate(imgs.iterrows()):
        imgPath = os.path.join(dir_path, f"{target_dir}/{row['id_code']}.png")
        img = cv2.imread(imgPath)
        row = idnx // 6
        col = idnx % 6
#         img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#         axis[row, col].imshow(img)
        imgName = os.path.split(imgPath)[1]
        new_imgPath = "./APTOS/NO_DR/"+imgName
        no_dir_img = cv2.imwrite(new_imgPath, img)
    plt.suptitle(class_label)
#     plt.show()

# %%
CLASS_ID = 0
save_No_DR_img(df_train[df_train.diagnosis == CLASS_ID], 'train_resized_images', CLASSS[CLASS_ID])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5beb623cd4b7> in <module>
#       1 CLASS_ID = 0
# ----> 2 save_No_DR_img(df_train[df_train.diagnosis == CLASS_ID], 'train_resized_images', CLASSS[CLASS_ID])
#
# NameError: name 'df_train' is not defined

# %%
def save_Mild_img(imgs, target_dir, class_label='0'):
    fig, axis = plt.subplots(2, 6, figsize=(15, 6))
    for idnx, (idx, row) in enumerate(imgs.iterrows()):
        imgPath = os.path.join(dir_path, f"{target_dir}/{row['id_code']}.png")
        img = cv2.imread(imgPath)
        row = idnx // 6
        col = idnx % 6
#         img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#         axis[row, col].imshow(img)
        imgName = os.path.split(imgPath)[1]
        new_imgPath = "./APTOS/Mild/"+imgName
        no_dir_img = cv2.imwrite(new_imgPath, img)
    plt.suptitle(class_label)
#     plt.show()

# %%
CLASS_ID = 1
save_Mild_img(df_train[df_train.diagnosis == CLASS_ID], 'train_resized_images', CLASSS[CLASS_ID])

# %%
def save_Moderate_img(imgs, target_dir, class_label='0'):
    fig, axis = plt.subplots(2, 6, figsize=(15, 6))
    for idnx, (idx, row) in enumerate(imgs.iterrows()):
        imgPath = os.path.join(dir_path, f"{target_dir}/{row['id_code']}.png")
        img = cv2.imread(imgPath)
        row = idnx // 6
        col = idnx % 6
#         img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#         axis[row, col].imshow(img)
        imgName = os.path.split(imgPath)[1]
        new_imgPath = "./APTOS/Moderate/"+imgName
        no_dir_img = cv2.imwrite(new_imgPath, img)
    plt.suptitle(class_label)
#     plt.show()

# %%
CLASS_ID = 2
save_Moderate_img(df_train[df_train.diagnosis == CLASS_ID], 'train_resized_images', CLASSS[CLASS_ID])

# %%
def save_Severe_img(imgs, target_dir, class_label='0'):
    fig, axis = plt.subplots(2, 6, figsize=(15, 6))
    for idnx, (idx, row) in enumerate(imgs.iterrows()):
        imgPath = os.path.join(dir_path, f"{target_dir}/{row['id_code']}.png")
        img = cv2.imread(imgPath)
        row = idnx // 6
        col = idnx % 6
#         img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#         axis[row, col].imshow(img)
        imgName = os.path.split(imgPath)[1]
        new_imgPath = "./APTOS/Severe/"+imgName
        no_dir_img = cv2.imwrite(new_imgPath, img)
    plt.suptitle(class_label)
    plt.show()

# %%
CLASS_ID = 3
save_Severe_img(df_train[df_train.diagnosis == CLASS_ID], 'train_resized_images', CLASSS[CLASS_ID])

# %%
def save_Proliferative_DR_img(imgs, target_dir, class_label='0'):
    fig, axis = plt.subplots(2, 6, figsize=(15, 6))
    for idnx, (idx, row) in enumerate(imgs.iterrows()):
        imgPath = os.path.join(dir_path, f"{target_dir}/{row['id_code']}.png")
        img = cv2.imread(imgPath)
        row = idnx // 6
        col = idnx % 6
#         img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#         axis[row, col].imshow(img)
        imgName = os.path.split(imgPath)[1]
        new_imgPath = "./APTOS/Proliferative_DR/"+imgName
        no_dir_img = cv2.imwrite(new_imgPath, img)
    plt.suptitle(class_label)
#     plt.show()

# %%
CLASS_ID = 4
save_Proliferative_DR_img(df_train[df_train.diagnosis == CLASS_ID], 'train_resized_images', CLASSS[CLASS_ID])
